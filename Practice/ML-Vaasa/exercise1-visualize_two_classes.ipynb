# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel (r'Part1_Exerc1_Data.xlsx')
# df.head()
df = df.iloc[4:]
df
# Out:
#                Unnamed: 0           Unnamed: 1 Unnamed: 2
# 4       1.346529803787536    2.269011626440069          1
# 5      0.4027578513274522   0.7025354043727929          1
# 6     -0.3037428757695264    2.496589752231848          1
# 7     -0.6626273823426203     5.71585847995064          1
# 8     -0.8179084527041256    1.845447778934756          1
# ..                    ...                  ...        ...
# 199    0.5730770038713482    1.619050406089946          1
# 200   -0.5462858277606911     2.84478432877952          1
# 201   -0.2655541642013657    1.095212575526969          1
# 202    -0.918410819035097    2.261551110393996          1
# 203    0.3307303673503452    1.281532609765135          1
#
# [200 rows x 3 columns]

# %%
x=df.iloc[:,0]
y=df.iloc[:,1]
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(x, y)

# %%
df=pd.read_csv(r'diabetes.csv')
df
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]
