# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from scipy.optimize import minimize # for optimization

# %%
def J(theta):
    return (theta[0]-5)**2+(theta[1]-5)**2

# %%
t0=np.linspace(0,10,100)
t1=np.linspace(0,10,100)

T0,T1=np.meshgrid(t0,t1)
Z=(T0-5)**2+(T1-5)**2

# %%
fig=plt.figure(figsize=(12,8))
ax=fig.gca(projection='3d')
surf=ax.plot_surface(T0,T1,Z,cmap=plt.cm.rainbow)
cset=ax.contour(T0,T1,Z,20,zdir='z',offset=0,cmap=plt.cm.rainbow)
fig.colorbar(surf,shrink=0.5,aspect=5)
plt.show()

# %%
plt.figure(figsize=(6,6))
cset=plt.contour(T0,T1,Z,20,cmap=plt.cm.rainbow)
fig.colorbar(surf,shrink=0.5,aspect=5)
plt.show()

# %%
plt.figure(figsize=(6,6))
cset=plt.contourf(T0,T1,Z,20,cmap=plt.cm.rainbow)
fig.colorbar(surf,shrink=0.5,aspect=5)
plt.show()

# %%
minimize(J,x0=[0,0],method='CG')
# Out:
#      fun: 2.4774723757749714e-18
#      jac: array([1.71271317e-08, 1.71271317e-08])
#  message: 'Optimization terminated successfully.'
#     nfev: 20
#      nit: 2
#     njev: 5
#   status: 0
#  success: True
#        x: array([5., 5.])

# %%
minimize(J,x0=[10,-3],method='CG')
# Out:
#      fun: 2.730455135196181e-16
#      jac: array([ 1.12131602e-08, -1.79405912e-08])
#  message: 'Optimization terminated successfully.'
#     nfev: 48
#      nit: 3
#     njev: 12
#   status: 0
#  success: True
#        x: array([5.        , 4.99999998])

# %%
minimize(J,x0=np.random.randn(2),method='CG')
# Out:
#      fun: 1.3008397942101204e-14
#      jac: array([-5.61726807e-08, -2.01852387e-07])
#  message: 'Optimization terminated successfully.'
#     nfev: 12
#      nit: 1
#     njev: 3
#   status: 0
#  success: True
#        x: array([4.99999996, 4.99999989])

# %%
result=minimize(J,x0=np.random.randn(2),method='CG')

# %%
result.success
# Out:
# True

# %%
minimize(J,x0=[10,-3],method='BFGS')
# Out:
#       fun: 2.4260200589213503e-12
#  hess_inv: array([[0.85955069, 0.22471904],
#        [0.22471904, 0.6404493 ]])
#       jac: array([-2.60680352e-06, -1.66758057e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 20
#       nit: 4
#      njev: 5
#    status: 0
#   success: True
#         x: array([4.99999869, 4.99999916])

# %%
def gradients(theta):
    return np.array([2*(theta[0]-5),2*(theta[1]-5)])

# %%
gradients([5,5])
# Out:
# array([0, 0])

# %%
minimize(J,x0=np.random.randn(2),method='CG',jac=gradients)
# Out:
#      fun: 0.0
#      jac: array([0., 0.])
#  message: 'Optimization terminated successfully.'
#     nfev: 5
#      nit: 2
#     njev: 5
#   status: 0
#  success: True
#        x: array([5., 5.])
