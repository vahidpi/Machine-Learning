# %%
import numpy as np 
import matplotlib.pyplot as plt 

greyhounds= 500 
labs= 500 

grey_height= 28 + 4 + np.random.randn(greyhounds) 
lab_height =24 + 4 + np.random.randn(labs) 
print(grey_height.shape)
plt.hist([grey_height , lab_height] , stacked=True, color=['r' , 'b']) 
plt.show( )
# Out:
# (500,)

# %%
a=10
b=10
a1=[1,4,6,7,9,4,3,1,8,9]
b1=[10,3.4,5.6,7,9.7,4,13,1,8,9]
plt.hist([a1,b1],stacked=True,color=['r','g'])
plt.show()
