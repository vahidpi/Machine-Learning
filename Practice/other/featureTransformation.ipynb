# %%
import sys

import scipy
import numpy as np
import matplotlib
import pandas as pd
import sklearn

# %%
# Load Dataset
fileURL = "/home/vahid/Documents/Personal/Machine Learning/DataSet/students/student/"
# fileURL = "/home/vahid/Documents/Personal/Machine Learning/DataSet/students/studentold/"
fileName="student-mat.csv"
dataSetNo=pd.read_csv(fileURL+fileName,sep=';') 
dataSetOr=pd.read_csv(fileURL+fileName,sep=';') 
dataSetNo.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# # Transforming Nominal Attributes

# %%
dataSetNo.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
mJob_field=dataSetNo.Mjob
print(mJob_field)
# Out:
# 0       at_home
# 1       at_home
# 2       at_home
# 3        health
# 4         other
#          ...
# 390    services
# 391    services
# 392       other
# 393    services
# 394       other
# Name: Mjob, Length: 395, dtype: object

# %%
mJob_field_unique=mJob_field.unique()
print(mJob_field_unique)
# Out:
# ['at_home' 'health' 'other' 'services' 'teacher']

# %%
from sklearn.preprocessing import LabelEncoder
gle = LabelEncoder()
mJob_labels = gle.fit_transform(mJob_field)
mJob_mappings = {index: label for index, label in enumerate(gle.classes_)}
mJob_mappings
# Out:
# {0: 'at_home', 1: 'health', 2: 'other', 3: 'services', 4: 'teacher'}

# %%
dataSetNo['Mjob'] = mJob_labels
dataSetNo.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu  Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4     0   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1     0     other  ...
# 2     GP   F   15       U     LE3       T     1     1     0     other  ...
# 3     GP   F   15       U     GT3       T     4     2     1  services  ...
# 4     GP   F   16       U     GT3       T     3     3     2     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# # Transforming Ordinal Attributes

# %%
dataSetOr.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
dataSetOr["Mjob"]
# Out:
# 0       at_home
# 1       at_home
# 2       at_home
# 3        health
# 4         other
#          ...
# 390    services
# 391    services
# 392       other
# 393    services
# 394       other
# Name: Mjob, Length: 395, dtype: object

# %%
np.unique(dataSetOr["Mjob"])
# Out:
# array(['at_home', 'health', 'other', 'services', 'teacher'], dtype=object)

# %%
gen_ord_map = {'at_home': 1, 'other': 2, 'health': 3, 
               'services': 4, 'teacher': 5}
print(gen_ord_map)
# Out:
# {'at_home': 1, 'other': 2, 'health': 3, 'services': 4, 'teacher': 5}

# %%
dataSetOr['Mjob_label'] = dataSetOr['Mjob'].map(gen_ord_map)
dataSetOr.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 Mjob_label
# 0        3     4     1     1       3        6   5   6   6          1
# 1        3     3     1     1       3        4   5   5   6          1
# 2        3     2     2     3       3       10   7   8  10          1
# 3        2     2     1     1       5        2  15  14  15          3
# 4        3     2     1     2       5        4   6  10  10          2
#
# [5 rows x 34 columns]
